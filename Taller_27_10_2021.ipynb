# %%
### Instituto Tecnológico Superior de San Luis Potosí, Capital. ###
![Logo ITSSLPC](images/logo2tec.jpg "ITSSLPC")

# Taller de Git, GitHub, MarkDown, Latex y Python
## ITSSLPC-ISC
## Actividades complementarias
![Logo Ninjas](images/Ninjas_Tec_Superior.jpg "ITSSLPC Ninjas")


[Apuntes](https://robo-tics-slp.net/ecuaciones)
# Out:
#   File "<ipython-input-1-83358562660f>", line 10
#     [Apuntes](https://robo-tics-slp.net/ecuaciones)
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 27/10/2021

# %%
# calculadora (+,-,*)
# ToDo
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
                  
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  6
# Las opciones válidas son del 1 al 5
# Vuelve a dar tú opción
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  12
# Las opciones válidas son del 1 al 5
# Vuelve a dar tú opción
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# calcular el índice de masa coprporal
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("4.- Índice de Masa Corporal")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
        
    elif opcion == 4:
        print("Índice de Masa Corporal")
        w = float(input("Dame tú peso en kilogramos"))
        h = float(input("Dame tú estatura en centrímetros"))
        bmi = w / ((h/100) **2)
        print("Tú índice de masa corporal es:", bmi)
                  
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 75
# Dame tú estatura en centrímetros 170
# Tú índice de masa corporal es: 25.95155709342561
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# calcular el índice de masa coprporal
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("4.- Índice de Masa Corporal")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    elif opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    elif opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
        
    elif opcion == 4:
        print("Índice de Masa Corporal")
        w = float(input("Dame tú peso en kilogramos"))
        h = float(input("Dame tú estatura en centrímetros"))
        bmi = w / ((h/100) **2)
        print("Tú índice de masa corporal es:", bmi)
        
        if bmi < 18.5:
            print("Peso bajo, necesitas comer tacos")
        elif ( (bmi >= 18.5) and (bmi <= 24.9)):
            print("Sigue así campeón(a)")
                
    elif opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    else:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
# Índice de Masa Corporal
# Dame tú peso en kilogramos 71
# Dame tú estatura en centrímetros 170
# Tú índice de masa corporal es: 24.56747404844291
# Sigue así campeón(a)
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 4.- Índice de Masa Corporal
# 5.- Salir
# -----------
# Dame tú opción  4
