# %% [markdown]
# ### Instituto Tecnológico Superior de San Luis Potosí, Capital. ###
# ![Logo ITSSLPC](images/logo2tec.jpg "ITSSLPC")
#
# # Taller de Git, GitHub, MarkDown, Latex y Python
# ## ITSSLPC-ISC
# ## Actividades complementarias
# ![Logo Ninjas](images/Ninjas_Tec_Superior.jpg "ITSSLPC Ninjas")
#
#
# [Apuntes](https://robo-tics-slp.net/ecuaciones)

# %% [markdown]
# ### 20/10/2021

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
# Out:
# El valor es igual a 30

# %%
a = 20

if a == 30:
    print("El valor es igual a 30")

# %%
a = 20

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
# Out:
# El valor es igual a 30

# %%
a = 31

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
# Out:
# El valor es mayor a 30

# %%
a = 30

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es igual a 30

# %%
a = 31

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es mayor a 30

# %%
a = 29

if a == 30:
    print("El valor es igual a 30")
elif a > 30:
    print("El valor es mayor a 30")
else:
    print("El valor es menor a 30")
# Out:
# El valor es menor a 30

# %% [markdown]
# ### Adivina si el valor _que nos proporciona el usuario_, mayor, igual o menor a 50

# %%
a = 49
if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# El valor es menor a 50

# %%
a = input("Ingrese el número que desea comparar")


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 49
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-c9d45c63545b> in <module>
#       4 if a == 50:
#       5     print("El valor es igual a 50")
# ----> 6 elif a > 50:
#       7     print("El valor es mayor a 50")
#       8 else:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 50
# El valor es igual a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 51
# El valor es mayor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 49
# El valor es menor a 50

# %%
a = int(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 50.50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-d1828c9eaad1> in <module>
# ----> 1 a = int(input("Ingrese el número que desea comparar"))
#       2
#       3
#       4 if a == 50:
#       5     print("El valor es igual a 50")
#
# ValueError: invalid literal for int() with base 10: '50.50'

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 50
# El valor es igual a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 51
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 49
# El valor es menor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 50.5
# El valor es mayor a 50

# %%
a = float(input("Ingrese el número que desea comparar"))


if a == 50:
    print("El valor es igual a 50")
elif a > 50:
    print("El valor es mayor a 50")
else:
    print("El valor es menor a 50")
# Out:
# Ingrese el número que desea comparar 200.58
# El valor es mayor a 50

# %% [markdown]
# ### Actualizar el repositorio ###
# ![GitHub](images/github.2021-10-19.png "ITSSLPC-ISC")
