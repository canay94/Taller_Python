# %% [markdown]
# ### Instituto Tecnológico Superior de San Luis Potosí, Capital. ###
# ![Logo ITSSLPC](images/logo2tec.jpg "ITSSLPC")
#
# # Taller de Git, GitHub, MarkDown, Latex y Python
# ## ITSSLPC-ISC
# ## Actividades complementarias
# ![Logo Ninjas](images/Ninjas_Tec_Superior.jpg "ITSSLPC Ninjas")
#
#
# [Apuntes](https://robo-tics-slp.net/ecuaciones)

# %%
# repaso

print("Hola mundo ")
# Out:
# Hola mundo

# %% [markdown]
# ### Solicitar datos
# #### Por lo regular cuando vamos a resolver un problema con una computadora y un lenguaje de programación
# - solicitamos datos
# - procesamos la información
# - entregamos resultados

# %%
# solicitar datos de cadenas 8strings)
print("¿Cómo te llamas ?")
# se usa la instrucción input para "atrapar" lo que escribe el usuario en el teclado
# y lo que escribimos en el teclado, se guarda en la variable "nombre"
nombre = input()
print("Gusto en conocerte: ", nombre)
# Out:
# ¿Cómo te llamas ?
#  Alejandro César
# Gusto en conocerte:  Alejandro César

# %%
dato = input("¿Cómo te llamas?")
print("Gusto en conocerte ", dato)
# Out:
# ¿Cómo te llamas? Alejandro César
# Gusto en conocerte  Alejandro César

# %% [markdown]
# ### Solictar datos numéricos

# %%
# solicitar datos de tipo entero
x = int(input("Dame el valor de x: "))
print("El valor de x es:", x)
# Out:
# Dame el valor de x:  35
# El valor de x es: 35

# %%
# solicitar datos de tipo flotante
x = float(input("Dame el valor de y: "))
print("El valor de x es: ", x)
# Out:
# Dame el valor de y:  50
# El valor de x es:  50.0

# %% [markdown]
# #### Desarrollar un programa en **Python** que _solicite_ **dos números**, _realice_ la **operación** de sumar e _imprima_ el **resultado**

# %%
# programa para sumar dos números(enteros)
x1 = int(input("Ingresa el primer valor: "))
x2 = int(input("Ingresa el segundo valor: "))
suma = print("La suma es: ", x1+x2)
# Out:
# Ingresa el primer valor:  80
# Ingresa el segundo valor:  20
# La suma es:  100

# %%
# programa para sumar dos números(enteros)
x1 = float(input("Ingresa el primer valor: "))
x2 = float(input("Ingresa el segundo valor: "))
suma = x1 + x2
suma = print("La suma es: ", suma)
# Out:
# Ingresa el primer valor:  12.55
# Ingresa el segundo valor:  32.89
# La suma es:  45.44
