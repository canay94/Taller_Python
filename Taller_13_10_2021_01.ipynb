# %%
print("Hola Mundo !!!")
# Out:
# Hola Mundo !!!

# %%
# concatena el valor de x
x = input("Dame el valor de x: ")
w = x + x
print(w)
# Out:
# Dame el valor de x:  30
# 3030

# %%
# convierte el valor de x a flotante
x = float(input("Dame el valor de x: "))
w = x + x
print(w)
# Out:
# Dame el valor de x:  30
# 60.0

# %% [markdown]
# #### Uso del IF

# %%
# if simple

# asignación de un valor a x
x = 20.000

if x == 20:
    print("El valor de x es 20 ")
# Out:
# El valor de x es 20

# %%
# if simple

# asignación de un valor a x
x = 20.01

if x == 20:
    print("El valor de x es 20 ")

# %%
# uso de los tabuladores
# if con else

# asignación de un valor a x
x = 20.01

if x == 20:
    print("El valor de x es 20 ")
    else:
        print("El valor de x NO es igual a 20 ")
# Out:
#   File "<ipython-input-17-965c18beb356>", line 8
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
# uso de los tabuladores
# if con else

# asignación de un valor a x
x = 20.01

if x == 20:
    print("El valor de x es 20 ")
else:
    print("El valor de x NO es igual a 20 ")
# Out:
# El valor de x NO es igual a 20

# %%
# if con else

# asignación de un valor a x
x = 20
# ==, !=, <=, >=, and, or

# uso del and y <=, >0 
if x >= 0 and x <= 20 :
    print("El valor de x es 20 ")
else:
    print("El valor de x NO es igual a 20 ")
# Out:
# El valor de x es 20

# %%
# if con else

# asignación de un valor a x
x = 21
# ==, !=, <=, >=, and, or

print("El valor de x es:", x)
# uso del and y <=, >0 
if ((x >= 0) and (x <= 20)) :
    print("El valor de x esta entre 0 y 20 ")
else:
    print("El valor de x es mayor a 20 ")
# Out:
# El valor de x es: 21
# El valor de x es mayor a 20

# %%
# if con else

# asignación de un valor a x
x = 21
# ==, !=, <=, >=, and, or

print("El valor de x es:", x)
# uso del and y <=, >0 
if ((x >= 0) and (x <= 20)) :
    print("El valor de x esta entre 0 y 20 ")
else:
    print("El valor de x es mayor a 20 ")
# Out:
# El valor de x es: 21
# El valor de x es mayor a 20

# %% [markdown]
# ## un poco de texto con LATEX
# $ f(x) = 0 $
#
# $ f(x) = x^2 + e^{2t} $
#
#
# $$ f(x) = 3x + 2x + 5 $$

# %% [markdown]
# ### poner referencias en Markdown
#
# [Tutorial LATEX](http://www.mat.uda.cl/hsalinas/cursos/2008/latex/doc-tutorial-latex.pdf)
