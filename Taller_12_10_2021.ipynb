# %% [markdown]
# ### Instituto Tecnológico Superior de San Luis Potosí, Capital. ###
# ![Logo ITSSLPC](logo2tec.jpg "Logo ITSSLPC")
#
# # Taller de Git, GitHub, MarkDown y Python
# ## ITSSLPC-ISC
# ## Actividades complementarias
# ![Logo Ninjas](Ninjas_Tec_Superior.jpg "ITSSLPC Ninjas")
#
#
# [Apuntes](https://robo-tics-slp.net/ecuaciones)

# %%
print("Hola Mundo !!!")
# Out:
# Hola Mundo !!!

# %%
# hacer una suma
# los toma como string a y b y concatena
a = input("Dame el valor de a: ")
b = input("Dame el valor de b: ")
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a:  23
# Dame el valor de b:  24
# El resultado es:  2324

# %%
print("hola " + "mundo ")
# Out:
# hola mundo

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es: ", r)
# Out:
# Dame el valor de a:  12.369
# Dame el valor de b:  10.357
# El resultado es:  22.726

# %% [markdown]
# ### solicitar datos, hacer operaciones y entregamos resultados
# ### formato de salida

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El resultado es:  %.2f " %(r) )
# Out:
# Dame el valor de a:  23.369
# Dame el valor de b:  21.2369
# El resultado es:  44.61

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.2f resultado es:  %.2f " %(r, r) )
# Out:
# Dame el valor de a:  23.258
# Dame el valor de b:  12.258
# El 35.52 resultado es:  35.52

# %%
# hacer una suma
a = float(input("Dame el valor de a: "))
b = float(input("Dame el valor de b: "))
r = a + b
print("El %.1f resultado es:  %.3f " %(r, r) )
# Out:
# Dame el valor de a:  12.236
# Dame el valor de b:  11.235
# El 23.5 resultado es:  23.471

# %% [markdown]
# ### Programa para convertir de kilómetros a millas
# ### 1 km = 0.621371 millas

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("El valor en millas es:  %.3f " %(millas) )
# Out:
# Dame el número de kilómetros:  14.95
# El valor en millas es:  9.289

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilómetros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f " %(k, millas) )
# Out:
# Dame el número de kilómetros:  14.99
# 15.0 Kilometro(s) equivale a: 9.31

# %%
# solicitar los kilometros
k = float(input("Dame el número de kilometros: "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# Dame el número de kilometros:  15.12
# 15.1 Kilometro(s) equivale a: 9.40 millas

# %% [markdown]
# ### Uso de condicionales IF

# %% [markdown]
# #### Pedimos el valor de kilómetros que se corrieron, los convertimos a millas
# #### Si el valor de las millas es = 10 entonces imprimir "Meta no cumplida"
# #### de otra forma impimir "Meta cumplida"

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor

# le faltan los dos puntos en el else
if millas = 10:
    print("Meta no cumplida")
else
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
#   File "<ipython-input-5-28cd55ab1ddc>", line 9
#     if millas = 10:
#               ^
# SyntaxError: invalid syntax

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  15.5
# 15.5 Kilometro(s) equivale a: 9.63 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  15.95
# 15.9 Kilometro(s) equivale a: 9.91 millas
# Meta cunplida

# %%
# solicitar los kilometros
k = float(input("¿Cuántos kilometros corriste ? "))
# 1 km = 0.621371 millas
factor = 0.621371
# calcular las millas
millas = k * factor
print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )  

if millas == 10:
    print("Meta no cumplida")
else:
    print("Meta cunplida")

# imprimir una salida como esta: 1 Kilometro(s) equivale a .621 millas
# print("%.1f Kilometro(s) equivale a: %.2f millas " %(k, millas) )
# Out:
# ¿Cuántos kilometros corriste ?  16.21371
# 16.2 Kilometro(s) equivale a: 10.07 millas
# Meta cunplida
