# %% [markdown]
# ### Instituto Tecnológico Superior de San Luis Potosí, Capital. ###
# ![Logo ITSSLPC](images/logo2tec.jpg "ITSSLPC")
#
# # Taller de Git, GitHub, MarkDown, Latex y Python
# ## ITSSLPC-ISC
# ## Actividades complementarias
# ![Logo Ninjas](images/Ninjas_Tec_Superior.jpg "ITSSLPC Ninjas")
#
#
# [Apuntes](https://robo-tics-slp.net/ecuaciones)

# %% [markdown]
# #### 26/10/2021

# %%
x = 10
while x > 0:
    print(x)
    print("Hola Mundo!!! ")
    x -= 1
# Out:
# 10
# Hola Mundo!!!
# 9
# Hola Mundo!!!
# 8
# Hola Mundo!!!
# 7
# Hola Mundo!!!
# 6
# Hola Mundo!!!
# 5
# Hola Mundo!!!
# 4
# Hola Mundo!!!
# 3
# Hola Mundo!!!
# 2
# Hola Mundo!!!
# 1
# Hola Mundo!!!

# %%
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("Hola Mundo!!! ")
    respuesta = "n"
    
print("Ya salió del while")
# Out:
# Hola Mundo!!!
# Ya salió del while

# %%
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("Menu del programa")
    print("1.- Opción 1 ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Esta es la opción 1")
    
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
    
print("Ya salió del while")
# Out:
# Menu del programa
# 1.- Opción 1
# 5.- Salir
# -----------
# Dame tú opción  1
# Esta es la opción 1
# Menu del programa
# 1.- Opción 1
# 5.- Salir
# -----------
# Dame tú opción  1
# Esta es la opción 1
# Menu del programa
# 1.- Opción 1
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!
# Ya salió del while

# %%
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("Menu del programa")
    print("1.- Opción 1 ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Esta es la opción 1")
    
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
    
print("Ya salió del while")
# Out:
# Menu del programa
# 1.- Opción 1
# 5.- Salir
# -----------
# Dame tú opción  2
# Menu del programa
# 1.- Opción 1
# 5.- Salir
# -----------
# Dame tú opción  12
# Menu del programa
# 1.- Opción 1
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!
# Ya salió del while

# %%
# calculadora (+,-,*)
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a")
        b = float(input("Dame el valor de b")
        c = a + b
        print("El resultado es:", c)
                  
    
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
# Out:
#   File "<ipython-input-5-f44f8e5706f9>", line 17
#     b = float(input("Dame el valor de b")
#     ^
# SyntaxError: invalid syntax

# %%
# calculadora (+,-,*)
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
                  
    
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  1
# Opción de suma
# Dame el valor de a 12.5
# Dame el valor de b 20.5
# El resultado es: 33.0
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  2
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    if opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
                  
    
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  2
# Opción de resta
# Dame el valor de a 25
# Dame el valor de b 10
# El resultado es: 15.0
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    if opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    if opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
                  
    
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  3
# Opción de multiplicación
# Dame el valor de a 12
# Dame el valor de b 5
# El resultado es: 60.0
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  6
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  7
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  8
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    if opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    if opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
                  
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    if opcion > 5:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
# Out:
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  7
# Las opciones válidas son del 1 al 5
# Vuelve a dar tú opción
# -----------------
# Menu del programa
# 1.- Suma
# 2.- Resta
# 3.- Multiplicación
# 5.- Salir
# -----------
# Dame tú opción  5
# Gracias !!!

# %%
# calculadora (+,-,*)
# mejorar el programa con el uso del elif y else
# ámbito del while
respuesta = "s"
while respuesta == "s":
    print("-----------------")
    print("Menu del programa")
    print("1.- Suma")
    print("2.- Resta ")
    print("3.- Multiplicación ")
    print("5.- Salir ")
    print("-----------")
    opcion = int(input("Dame tú opción "))
    
    if opcion == 1:
        print("Opción de suma")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a + b
        print("El resultado es:", c)
     
    if opcion == 2:
        print("Opción de resta")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a - b
        print("El resultado es:", c)
    
    if opcion == 3:
        print("Opción de multiplicación")
        a = float(input("Dame el valor de a"))
        b = float(input("Dame el valor de b"))
        c = a * b
        print("El resultado es:", c)
                  
    if opcion == 5:
        print("Gracias !!! ")
        respuesta = "n"
        
    if opcion > 5:
        print("Las opciones válidas son del 1 al 5")
        print("Vuelve a dar tú opción")
